# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def gradient_descent(x,y,alpha=0.01,epoch=30):
  m = np.shape(x)[0]
  n = np.shape(x)[1]
  x = np.concatenate((np.ones((m,1)),x),axis = 1)
  w = np.random.randn(n+1,)
  cost_history_list = []
  for currant_iteration in np.arange(epoch):
    y_estimated = x.dot(w)
    error = y_estimated - y
    cost = (1/2*m)*np.sum(error**2)
    gradient = (1/m)*x.T.dot(error)
    w = w - alpha * gradient
    if currant_iteration % 10 == 0:
      print(f"cost:{cost}\t iteration: {currant_iteration}")
    cost_history_list.append(cost)
  return w, cost_history_list, y_estimated

# %%
rng = np.random.RandomState(10)
x = 10*rng.rand(24,1)
y = 0.9+np.dot(x,[2.2])

# %%
weight, cost_history_list, h = gradient_descent(x,y,0.001,500)

plt.plot(np.arange(len(cost_history_list)), cost_history_list)
plt.xlabel("Number of iteration epoch")
plt.ylabel("Cost function J(Theta)")
plt.title("Gradient descent")
plt.show()
# Out:
# cost:44998.61358238243	 iteration: 0
# cost:22396.964975738174	 iteration: 10
# cost:11156.01581267847	 iteration: 20
# cost:5565.279468693567	 iteration: 30
# cost:2784.661223574671	 iteration: 40
# cost:1401.6478266121655	 iteration: 50
# cost:713.7297199777449	 iteration: 60
# cost:371.5157174960998	 iteration: 70
# cost:201.23707784991512	 iteration: 80
# cost:116.47039662715272	 iteration: 90
# cost:74.23323099696674	 iteration: 100
# cost:53.148380152256216	 iteration: 110
# cost:42.583950620386354	 iteration: 120
# cost:37.252197801458095	 iteration: 130
# cost:34.52327475560333	 iteration: 140
# cost:33.089232596788165	 iteration: 150
# cost:32.29956478615166	 iteration: 160
# cost:31.830741925207278	 iteration: 170
# cost:31.52185579979877	 iteration: 180
# cost:31.292877400192854	 iteration: 190
# cost:31.104002773561227	 iteration: 200
# cost:30.935433796186807	 iteration: 210
# cost:30.77732219643912	 iteration: 220
# cost:30.62476824239196	 iteration: 230
# cost:30.47533335291171	 iteration: 240
# cost:30.32780300162686	 iteration: 250
# cost:30.18157145060117	 iteration: 260
# cost:30.036335749289634	 iteration: 270
# cost:29.891943545726814	 iteration: 280
# cost:29.74831739580437	 iteration: 290
# cost:29.605417118659638	 iteration: 300
# cost:29.463221074195264	 iteration: 310
# cost:29.321716851465826	 iteration: 320
# cost:29.180896637535046	 iteration: 330
# cost:29.040754914151552	 iteration: 340
# cost:28.901287312159493	 iteration: 350
# cost:28.762490041704506	 iteration: 360
# cost:28.62435960881144	 iteration: 370
# cost:28.4868926743871	 iteration: 380
# cost:28.350085984059348	 iteration: 390
# cost:28.213936333244924	 iteration: 400
# cost:28.07844054974029	 iteration: 410
# cost:27.94359548502564	 iteration: 420
# cost:27.809398009904037	 iteration: 430
# cost:27.675845012296982	 iteration: 440
# cost:27.542933396110335	 iteration: 450
# cost:27.410660080636255	 iteration: 460
# cost:27.279022000218767	 iteration: 470
# cost:27.148016104052278	 iteration: 480
# cost:27.017639356046388	 iteration: 490

# %%
plt.scatter(np.arange(len(cost_history_list)), cost_history_list)

# %%
plt.plot(y, 'b')
plt.plot(h, '.r')

# %%
weight
# Out:
# array([0.28414734, 2.29296838])

# %%
def plot_regression_line(x, y, w):
    plt.scatter(x,y)
    y_pred = w[0] + w[1]*x
    plt.plot(x, y_pred, color = "g")
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()

# %%
plot_regression_line(x, y, weight)
